# %% [markdown]
# <a href="https://colab.research.google.com/github/BF667-IDLE/votepurchase-multiple-model/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # votepurchase multiple model colab ver
#
#
# with tweaks

# %%
#@title install
# %%capture


# !git clone https://github.com/BF667-IDLE/votepurchase-multiple-model.git main

# %cd main
# !uv pip install -r requirements.txt -q
# !uv pip install spaces
import os; os.kill(os.getpid(), 9)  # This restarts the runtime to reload Colab's preloaded modules, preventing conflicts.

# %%
HF_TOKEN = "" #@param {type: "string"}
CIVITAI_API_KEY = "" #@param {type: "string"}


# HF TRANSFER (optional) can speed up downloads from Hugging Face, but sometimes the downloads might fail.
# %env HF_HUB_ENABLE_HF_TRANSFER=1
# %env HF_HUB_DISABLE_XET=1
# %env HF_TOKEN=HF_TOKEN
# !uv pip install hf_transfer -q
# %env CIVITAI_API_KEY=CIVITAI_API_KEY

# %%
#@title run the app

# !git pull -q


# %cd /content/main
# !python app.py
